# %%
# !pip install -q langchain langchain-community faiss-cpu sentence-transformers pymongo gradio transformers accelerate sentencepiece
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.5 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 83.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 78.4 MB/s eta 0:00:00:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xmanager 0.7.1 requires sqlalchemy==1.2.19, but you have sqlalchemy 2.0.45 which is incompatible.

# %%
# !ls /kaggle/input
# Out:
# yoga-kb

# %%
# !mkdir -p /kaggle/working/yoga-rag-microapp/backend/rag
# !mkdir -p /kaggle/working/yoga-rag-microapp/backend/llm
# !mkdir -p /kaggle/working/yoga-rag-microapp/frontend
# !mkdir -p /kaggle/working/yoga-rag-microapp/data
# !mkdir -p /kaggle/working/yoga-rag-microapp/assets

# !mkdir -p /kaggle/working/yoga-rag-microapp/faiss_index   # generated (will be ignored in git)

# %%
# !cp -r /kaggle/input/yoga-kb/yoga_docs /kaggle/working/yoga-rag-microapp/data/
# !ls /kaggle/working/yoga-rag-microapp/data/yoga_docs | head
# Out:
# 01_surya_namaskar.txt
# 02_tadasana.txt
# 03_adho_mukha_svanasana.txt
# 04_bhujangasana.txt
# 05_trikonasana.txt
# 06_virabhadrasana_1.txt
# 07_virabhadrasana_2.txt
# 08_balasana.txt
# 09_setu_bandhasana.txt
# 10_shavasana.txt

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/backend/config.py
from pathlib import Path
import os

# ONLY CHANGE: __file__ fallback for notebook environments
try:
    PROJECT_ROOT = Path(__file__).resolve().parents[1]
except NameError:
    # Notebook fallback
    cwd = Path(os.getcwd()).resolve()

    # If already in project root
    if (cwd / "backend").exists() and (cwd / "frontend").exists():
        PROJECT_ROOT = cwd
    # If inside /kaggle/working and project folder exists
    elif (cwd / "yoga-rag-microapp").exists():
        PROJECT_ROOT = cwd / "yoga-rag-microapp"
    else:
        # Last fallback: search upwards
        PROJECT_ROOT = None
        for p in [cwd] + list(cwd.parents):
            if (p / "backend").exists() and (p / "frontend").exists():
                PROJECT_ROOT = p
                break
        if PROJECT_ROOT is None:
            raise RuntimeError("Could not locate project root. Please cd into project folder.")

DATA_PATH = PROJECT_ROOT / "data" / "yoga_docs"
VECTOR_DB_PATH = PROJECT_ROOT / "faiss_index"
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/backend/config.py

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/.gitignore
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
#
# .env
# faiss_index/
# *.zip
#
# # Kaggle generated
# /kaggle/
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/.gitignore

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/.env.example
# MONGO_URI=mongodb+srv://<username>:<password>@<cluster>.mongodb.net/?retryWrites=true&w=majority
# DB_NAME=nextyou_rag
# COLLECTION_NAME=query_logs
#
# MODEL_NAME=google/flan-t5-xl
# EMBEDDING_MODEL=sentence-transformers/all-mpnet-base-v2
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/.env.example

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/requirements.txt
# langchain
# langchain-community
# faiss-cpu
# sentence-transformers
# pymongo
# gradio
# transformers
# accelerate
# sentencepiece
# torch
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/requirements.txt

# %%
# !pip install -r /kaggle/working/yoga-rag-microapp/requirements.txt
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.3.27)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (0.3.31)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 3)) (1.13.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 5)) (4.15.5)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (5.49.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 7)) (4.57.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 8)) (1.11.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 9)) (0.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (2.8.0+cu126)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (2.11.10)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (2.0.45)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 3)) (25.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 5)) (2.8.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.119.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (3.11.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.14.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.38.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2025.10.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 7)) (3.20.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 7)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 7)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 7)) (0.6.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (3.11)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (1.2.1rc0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (1.33)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (14.2.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r /kaggle/working/yoga-rag-microapp/requirements.txt (line 6)) (0.1.2)

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/backend/safety.py
def check_safety(query: str):
    query = query.lower()

    pregnancy_keywords = [
        "pregnant", "pregnancy", "trimester", "prenatal"
    ]

    medical_keywords = [
        "hernia", "glaucoma", "high blood pressure",
        "bp", "hypertension", "surgery", "injury",
        "chronic pain", "operation"
    ]

    for word in pregnancy_keywords:
        if word in query:
            return {"isUnsafe": True, "reason": "pregnancy"}

    for word in medical_keywords:
        if word in query:
            return {"isUnsafe": True, "reason": "medical_condition"}

    return {"isUnsafe": False, "reason": None}
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/backend/safety.py

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/backend/db.py
import os
from datetime import datetime
from pymongo import MongoClient

def get_mongo_uri():
    # 1) Kaggle secrets
    try:
        from kaggle_secrets import UserSecretsClient
        user_secrets = UserSecretsClient()
        uri = user_secrets.get_secret("MONGO_URI")
        if uri and uri.strip():
            print(" Loaded MONGO_URI from Kaggle Secrets")
            return uri.strip()
    except Exception as e:
        print("Kaggle secret missing. Will try env var.")
        print("Reason:", str(e))

    # 2) Local env
    uri = os.getenv("MONGO_URI", "")
    if uri and uri.strip():
        print("Loaded MONGO_URI from environment")
        return uri.strip()

    print("No MONGO_URI found - DB logging disabled.")
    return None


MONGO_URI = get_mongo_uri()

client = MongoClient(MONGO_URI) if MONGO_URI else None

DB_NAME = os.getenv("DB_NAME", "nextyou_rag")
COLLECTION_NAME = os.getenv("COLLECTION_NAME", "query_logs")

collection = None
if client:
    db = client[DB_NAME]
    collection = db[COLLECTION_NAME]


def log_query(query, retrieved_chunks, answer, is_unsafe, safety_reason=None):
    if collection is None:
        return  # no DB logging

    collection.insert_one({
        "query": query,
        "retrieved_chunks": retrieved_chunks,
        "answer": answer,
        "isUnsafe": is_unsafe,
        "safety_reason": safety_reason,
        "timestamp": datetime.utcnow()
    })
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/backend/db.py

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/backend/rag/ingest.py
from backend.config import DATA_PATH, VECTOR_DB_PATH

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS


def load_documents():
    docs = []
    for file_path in sorted(DATA_PATH.glob("*.txt")):
        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read()
            docs.append(Document(page_content=content, metadata={"source": file_path.name}))
    return docs


def build_faiss_index():
    docs = load_documents()

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1500,
        chunk_overlap=150
    )

    chunks = splitter.split_documents(docs)

    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2"
    )

    db = FAISS.from_documents(chunks, embeddings)
    db.save_local(str(VECTOR_DB_PATH))

    print(f" FAISS index built with {len(chunks)} chunks at: {VECTOR_DB_PATH}")


if __name__ == "__main__":
    build_faiss_index()
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/backend/rag/ingest.py

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/backend/rag/retriever.py
from backend.config import VECTOR_DB_PATH

from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS


def retrieve_chunks(query, k=8):
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2"
    )

    vectorstore = FAISS.load_local(
        str(VECTOR_DB_PATH),
        embeddings,
        allow_dangerous_deserialization=True
    )

    results = vectorstore.similarity_search(query, k=k)

    retrieved = []
    for idx, doc in enumerate(results):
        retrieved.append({
            "chunk_id": idx,
            "source": doc.metadata.get("source", "unknown"),
            "content": doc.page_content
        })

    return retrieved
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/backend/rag/retriever.py

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/backend/llm/local_llm.py
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
import os

MODEL_NAME = os.getenv("MODEL_NAME", "google/flan-t5-xl")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSeq2SeqLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,
    device_map="auto"
)

def generate_answer(query, retrieved_chunks, is_unsafe=False):
    context = "\n\n".join(
        f"Source: {c['source']}\n{c['content']}"
        for c in retrieved_chunks
    ).strip()

    safety_note = ""
    if is_unsafe:
        safety_note = (
            "SAFETY RULES:\n"
            "- The query involves pregnancy or a medical condition.\n"
            "- Do NOT give medical advice.\n"
            "- Provide a gentle warning and recommend consulting a professional.\n\n"
        )

    prompt = f"""
You are a yoga and wellness assistant.

{safety_note}
INSTRUCTION:
Answer ONLY using the context.
If the answer is not in the context, reply exactly:
"I’m not sure based on the provided knowledge base."

CONTEXT:
{context}

QUESTION:
{query}

ANSWER:
""".strip()

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=1024
    )

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=220,
            temperature=0.2,
            do_sample=True
        )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/backend/llm/local_llm.py

# %%
# %%writefile /kaggle/working/yoga-rag-microapp/frontend/app_gradio.py
import gradio as gr
from pathlib import Path
import os
import sys

# ONLY CHANGE: __file__ fallback for notebook environments
try:
    PROJECT_ROOT = Path(__file__).resolve().parents[1]
except NameError:
    cwd = Path(os.getcwd()).resolve()
    if (cwd / "backend").exists():
        PROJECT_ROOT = cwd
    else:
        PROJECT_ROOT = cwd / "yoga-rag-microapp"

sys.path.append(str(PROJECT_ROOT / "backend"))

from safety import check_safety
from rag.retriever import retrieve_chunks
from llm.local_llm import generate_answer
from db import log_query


def answer_question(query):
    if not query.strip():
        return "Please enter a question.", "", ""

    safety = check_safety(query)
    is_unsafe = safety["isUnsafe"]
    reason = safety["reason"]

    retrieved_chunks = retrieve_chunks(query, k=3)

    answer = generate_answer(
        query=query,
        retrieved_chunks=retrieved_chunks,
        is_unsafe=is_unsafe
    )

    sources = "\n".join(
        f"- {chunk['source']}" for chunk in retrieved_chunks
    ) or "No sources found."

    warning = ""
    if is_unsafe:
        warning = (
            "⚠️ SAFETY WARNING: This query may involve health risks.\n"
            "Please consult a doctor or certified yoga therapist."
        )

    log_query(
        query=query,
        retrieved_chunks=retrieved_chunks,
        answer=answer,
        is_unsafe=is_unsafe,
        safety_reason=reason
    )

    return answer, sources, warning


demo = gr.Interface(
    fn=answer_question,
    inputs=gr.Textbox(label="Ask anything about yoga"),
    outputs=[
        gr.Textbox(label="Answer"),
        gr.Textbox(label="Sources Used"),
        gr.Textbox(label="Safety Warning")
    ],
    title="🧘 Ask Me Anything About Yoga",
    description="RAG wellness assistant using FAISS retrieval + safety guardrails + MongoDB logging."
)

demo.launch(share=True)
# Out:
# Overwriting /kaggle/working/yoga-rag-microapp/frontend/app_gradio.py

# %%
# %cd /kaggle/working/yoga-rag-microapp
# !python -m backend.rag.ingest
# !python -m frontend.app_gradio
# Out:
# /kaggle/working/yoga-rag-microapp
# /kaggle/working/yoga-rag-microapp/backend/rag/ingest.py:28: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# 2026-01-12 03:45:30.281461: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768189530.446039     237 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768189530.497138     237 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768189530.892663     237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768189530.892707     237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768189530.892715     237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768189530.892722     237 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# modules.json: 100%|████████████████████████████| 349/349 [00:00<00:00, 3.53MB/s]
# config_sentence_transformers.json: 100%|███████| 116/116 [00:00<00:00, 1.48MB/s]
# README.md: 10.5kB [00:00, 42.8MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 540kB/s]
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 7.55MB/s]
# model.safetensors: 100%|███████████████████| 90.9M/90.9M [00:01<00:00, 66.1MB/s]
# tokenizer_config.json: 100%|███████████████████| 350/350 [00:00<00:00, 2.79MB/s]
# vocab.txt: 232kB [00:00, 13.2MB/s]
# tokenizer.json: 466kB [00:00, 32.0MB/s]
# special_tokens_map.json: 100%|█████████████████| 112/112 [00:00<00:00, 1.09MB/s]
# config.json: 100%|█████████████████████████████| 190/190 [00:00<00:00, 1.91MB/s]
#  FAISS index built with 30 chunks at: /kaggle/working/yoga-rag-microapp/faiss_index
# tokenizer_config.json: 2.54kB [00:00, 12.7MB/s]
# spiece.model: 100%|███████████████████████████| 792k/792k [00:01<00:00, 568kB/s]
# tokenizer.json: 2.42MB [00:00, 50.2MB/s]
# special_tokens_map.json: 2.20kB [00:00, 11.6MB/s]
# config.json: 1.44kB [00:00, 7.48MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2026-01-12 03:46:04.731537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768189564.753172     271 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768189564.760248     271 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768189564.777649     271 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768189564.777677     271 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768189564.777680     271 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768189564.777684     271 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# model.safetensors.index.json: 53.0kB [00:00, 170MB/s]
# Fetching 2 files:   0%|                                   | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|             | 0.00/1.95G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0%|             | 0.00/9.45G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0%| | 52.0k/9.45G [00:01<76:49:49, 34.2kB/s]
# model-00002-of-00002.safetensors:   0%|     | 1.07M/1.95G [00:01<48:28, 670kB/s]
#
# model-00001-of-00002.safetensors:   0%| | 89.4k/9.45G [00:02<57:26:25, 45.7kB/s]
#
# model-00001-of-00002.safetensors:   0%|    | 4.01M/9.45G [00:02<58:37, 2.69MB/s]
# model-00002-of-00002.safetensors:   0%|    | 5.37M/1.95G [00:03<18:59, 1.71MB/s]
#
# model-00001-of-00002.safetensors:   1%|    | 71.1M/9.45G [00:03<04:53, 32.0MB/s]
# model-00002-of-00002.safetensors:   4%|▏   | 72.4M/1.95G [00:03<01:09, 27.1MB/s]
# model-00002-of-00002.safetensors:  11%|▌    | 206M/1.95G [00:04<00:19, 87.7MB/s]
#
# model-00001-of-00002.safetensors:   1%|     | 138M/9.45G [00:04<03:11, 48.7MB/s]
# model-00002-of-00002.safetensors:  14%|▊     | 273M/1.95G [00:04<00:15, 110MB/s]
#
# model-00001-of-00002.safetensors:   2%|     | 205M/9.45G [00:04<01:55, 79.9MB/s]
# model-00002-of-00002.safetensors:  17%|█     | 340M/1.95G [00:04<00:11, 144MB/s]
#
# model-00001-of-00002.safetensors:   3%|▏     | 272M/9.45G [00:04<01:24, 108MB/s]
#
# model-00001-of-00002.safetensors:   4%|▏     | 340M/9.45G [00:05<01:00, 151MB/s]
# model-00002-of-00002.safetensors:  21%|█▎    | 408M/1.95G [00:05<00:10, 152MB/s]
# model-00002-of-00002.safetensors:  23%|█▎    | 440M/1.95G [00:05<00:09, 160MB/s]
#
# model-00001-of-00002.safetensors:   4%|▎     | 407M/9.45G [00:05<00:49, 182MB/s]
#
# model-00001-of-00002.safetensors:   5%|▎     | 474M/9.45G [00:05<00:42, 210MB/s]
# model-00002-of-00002.safetensors:  28%|█▋    | 542M/1.95G [00:05<00:06, 210MB/s]
#
# model-00001-of-00002.safetensors:   6%|▎     | 541M/9.45G [00:05<00:33, 264MB/s]
#
# model-00001-of-00002.safetensors:   6%|▍     | 608M/9.45G [00:05<00:31, 280MB/s]
# model-00002-of-00002.safetensors:  31%|█▉    | 609M/1.95G [00:05<00:06, 215MB/s]
# model-00002-of-00002.safetensors:  38%|██▎   | 743M/1.95G [00:06<00:03, 312MB/s]
#
# model-00001-of-00002.safetensors:   7%|▍     | 676M/9.45G [00:06<00:31, 276MB/s]
# model-00002-of-00002.safetensors:  45%|██▋   | 878M/1.95G [00:06<00:02, 384MB/s]
# model-00002-of-00002.safetensors:  48%|██▉   | 945M/1.95G [00:06<00:02, 400MB/s]
# model-00002-of-00002.safetensors:  52%|██▌  | 1.01G/1.95G [00:06<00:02, 415MB/s]
# model-00002-of-00002.safetensors:  55%|██▊  | 1.08G/1.95G [00:06<00:02, 389MB/s]
#
# model-00001-of-00002.safetensors:   8%|▍     | 744M/9.45G [00:06<00:51, 169MB/s]
#
# model-00001-of-00002.safetensors:   9%|▌     | 883M/9.45G [00:06<00:32, 263MB/s]
# model-00002-of-00002.safetensors:  59%|██▉  | 1.14G/1.95G [00:07<00:02, 293MB/s]
#
# model-00001-of-00002.safetensors:  10%|▌     | 950M/9.45G [00:07<00:28, 301MB/s]
#
# model-00001-of-00002.safetensors:  11%|▌    | 1.01G/9.45G [00:07<00:30, 272MB/s]
# model-00002-of-00002.safetensors:  62%|███  | 1.21G/1.95G [00:07<00:03, 218MB/s]
#
# model-00001-of-00002.safetensors:  11%|▌    | 1.08G/9.45G [00:07<00:29, 285MB/s]
# model-00002-of-00002.safetensors:  66%|███▎ | 1.28G/1.95G [00:07<00:02, 244MB/s]
#
# model-00001-of-00002.safetensors:  12%|▌    | 1.15G/9.45G [00:07<00:27, 301MB/s]
#
# model-00001-of-00002.safetensors:  13%|▋    | 1.22G/9.45G [00:07<00:24, 336MB/s]
# model-00002-of-00002.safetensors:  69%|███▍ | 1.35G/1.95G [00:08<00:02, 266MB/s]
#
# model-00001-of-00002.safetensors:  14%|▋    | 1.28G/9.45G [00:08<00:25, 318MB/s]
#
# model-00001-of-00002.safetensors:  14%|▋    | 1.35G/9.45G [00:08<00:24, 327MB/s]
# model-00002-of-00002.safetensors:  76%|███▊ | 1.48G/1.95G [00:08<00:01, 277MB/s]
# model-00002-of-00002.safetensors:  79%|███▉ | 1.55G/1.95G [00:08<00:01, 295MB/s]
#
# model-00001-of-00002.safetensors:  15%|▊    | 1.43G/9.45G [00:08<00:28, 281MB/s]
# model-00002-of-00002.safetensors:  83%|████▏| 1.61G/1.95G [00:08<00:01, 323MB/s]
#
# model-00001-of-00002.safetensors:  16%|▊    | 1.49G/9.45G [00:08<00:28, 283MB/s]
#
# model-00001-of-00002.safetensors:  17%|▊    | 1.56G/9.45G [00:09<00:23, 338MB/s]
# model-00002-of-00002.safetensors:  86%|████▎| 1.68G/1.95G [00:09<00:01, 261MB/s]
#
# model-00001-of-00002.safetensors:  17%|▊    | 1.63G/9.45G [00:09<00:22, 345MB/s]
#
# model-00001-of-00002.safetensors:  18%|▉    | 1.70G/9.45G [00:09<00:19, 398MB/s]
# model-00002-of-00002.safetensors:  90%|████▍| 1.75G/1.95G [00:09<00:00, 237MB/s]
#
# model-00001-of-00002.safetensors:  19%|▉    | 1.76G/9.45G [00:09<00:28, 269MB/s]
# model-00002-of-00002.safetensors:  93%|████▋| 1.82G/1.95G [00:09<00:00, 218MB/s]
#
# model-00001-of-00002.safetensors:  19%|▉    | 1.83G/9.45G [00:09<00:24, 316MB/s]
# model-00002-of-00002.safetensors:  97%|████▊| 1.88G/1.95G [00:10<00:00, 200MB/s]
# model-00002-of-00002.safetensors: 100%|█████| 1.95G/1.95G [00:10<00:00, 178MB/s]
#
#
# model-00001-of-00002.safetensors:  20%|█    | 1.90G/9.45G [00:11<00:52, 145MB/s]
#
# model-00001-of-00002.safetensors:  21%|▊   | 1.97G/9.45G [00:12<01:24, 88.9MB/s]
#
# model-00001-of-00002.safetensors:  22%|█    | 2.03G/9.45G [00:12<01:04, 115MB/s]
#
# model-00001-of-00002.safetensors:  22%|█    | 2.10G/9.45G [00:12<00:52, 141MB/s]
#
# model-00001-of-00002.safetensors:  23%|█▏   | 2.17G/9.45G [00:13<00:43, 169MB/s]
#
# model-00001-of-00002.safetensors:  24%|█▏   | 2.24G/9.45G [00:13<00:35, 201MB/s]
#
# model-00001-of-00002.safetensors:  25%|█▎   | 2.37G/9.45G [00:13<00:21, 331MB/s]
#
# model-00001-of-00002.safetensors:  27%|█▎   | 2.50G/9.45G [00:13<00:16, 428MB/s]
#
# model-00001-of-00002.safetensors:  27%|█▎   | 2.57G/9.45G [00:14<00:26, 257MB/s]
#
# model-00001-of-00002.safetensors:  31%|█▌   | 2.91G/9.45G [00:14<00:11, 546MB/s]
#
# model-00001-of-00002.safetensors:  33%|█▋   | 3.11G/9.45G [00:14<00:10, 589MB/s]
#
# model-00001-of-00002.safetensors:  34%|█▋   | 3.24G/9.45G [00:14<00:09, 658MB/s]
#
# model-00001-of-00002.safetensors:  36%|█▊   | 3.38G/9.45G [00:15<00:10, 596MB/s]
#
# model-00001-of-00002.safetensors:  37%|█▊   | 3.50G/9.45G [00:15<00:10, 569MB/s]
#
# model-00001-of-00002.safetensors:  39%|█▉   | 3.64G/9.45G [00:15<00:08, 653MB/s]
#
# model-00001-of-00002.safetensors:  40%|█▉   | 3.78G/9.45G [00:15<00:08, 690MB/s]
#
# model-00001-of-00002.safetensors:  41%|██   | 3.91G/9.45G [00:15<00:07, 740MB/s]
#
# model-00001-of-00002.safetensors:  43%|██▏  | 4.05G/9.45G [00:15<00:07, 730MB/s]
#
# model-00001-of-00002.safetensors:  44%|██▏  | 4.18G/9.45G [00:16<00:08, 595MB/s]
#
# model-00001-of-00002.safetensors:  45%|██▏  | 4.25G/9.45G [00:16<00:09, 573MB/s]
#
# model-00001-of-00002.safetensors:  46%|██▎  | 4.36G/9.45G [00:16<00:08, 603MB/s]
#
# model-00001-of-00002.safetensors:  47%|██▎  | 4.43G/9.45G [00:16<00:10, 488MB/s]
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.50G/9.45G [00:17<00:11, 423MB/s]
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.56G/9.45G [00:17<00:13, 353MB/s]
#
# model-00001-of-00002.safetensors:  49%|██▍  | 4.63G/9.45G [00:17<00:14, 341MB/s]
#
# model-00001-of-00002.safetensors:  50%|██▍  | 4.70G/9.45G [00:17<00:15, 316MB/s]
#
# model-00001-of-00002.safetensors:  51%|██▌  | 4.78G/9.45G [00:18<00:20, 226MB/s]
#
# model-00001-of-00002.safetensors:  51%|██▌  | 4.85G/9.45G [00:18<00:17, 263MB/s]
#
# model-00001-of-00002.safetensors:  52%|██▌  | 4.93G/9.45G [00:19<00:21, 213MB/s]
#
# model-00001-of-00002.safetensors:  53%|██▋  | 5.00G/9.45G [00:19<00:21, 208MB/s]
#
# model-00001-of-00002.safetensors:  54%|██▋  | 5.06G/9.45G [00:19<00:17, 247MB/s]
#
# model-00001-of-00002.safetensors:  54%|██▋  | 5.13G/9.45G [00:19<00:18, 239MB/s]
#
# model-00001-of-00002.safetensors:  55%|██▊  | 5.20G/9.45G [00:20<00:16, 250MB/s]
#
# model-00001-of-00002.safetensors:  56%|██▊  | 5.27G/9.45G [00:21<00:32, 130MB/s]
#
# model-00001-of-00002.safetensors:  56%|██▊  | 5.33G/9.45G [00:21<00:25, 161MB/s]
#
# model-00001-of-00002.safetensors:  57%|██▊  | 5.41G/9.45G [00:21<00:20, 194MB/s]
#
# model-00001-of-00002.safetensors:  59%|██▉  | 5.60G/9.45G [00:22<00:13, 280MB/s]
#
# model-00001-of-00002.safetensors:  60%|██▉  | 5.66G/9.45G [00:22<00:12, 314MB/s]
#
# model-00001-of-00002.safetensors:  61%|███  | 5.73G/9.45G [00:22<00:11, 311MB/s]
#
# model-00001-of-00002.safetensors:  61%|███  | 5.80G/9.45G [00:22<00:10, 348MB/s]
#
# model-00001-of-00002.safetensors:  62%|███  | 5.87G/9.45G [00:22<00:10, 353MB/s]
#
# model-00001-of-00002.safetensors:  63%|███▏ | 5.95G/9.45G [00:22<00:10, 345MB/s]
#
# model-00001-of-00002.safetensors:  64%|███▏ | 6.01G/9.45G [00:23<00:18, 189MB/s]
#
# model-00001-of-00002.safetensors:  64%|███▏ | 6.08G/9.45G [00:23<00:15, 218MB/s]
#
# model-00001-of-00002.safetensors:  66%|███▎ | 6.22G/9.45G [00:24<00:10, 311MB/s]
#
# model-00001-of-00002.safetensors:  66%|███▎ | 6.28G/9.45G [00:24<00:09, 321MB/s]
#
# model-00001-of-00002.safetensors:  68%|███▍ | 6.38G/9.45G [00:24<00:11, 275MB/s]
#
# model-00001-of-00002.safetensors:  68%|███▍ | 6.45G/9.45G [00:24<00:10, 281MB/s]
#
# model-00001-of-00002.safetensors:  70%|███▍ | 6.58G/9.45G [00:25<00:07, 406MB/s]
#
# model-00001-of-00002.safetensors:  70%|███▌ | 6.65G/9.45G [00:25<00:06, 402MB/s]
#
# model-00001-of-00002.safetensors:  72%|███▌ | 6.78G/9.45G [00:25<00:05, 465MB/s]
#
# model-00001-of-00002.safetensors:  73%|███▋ | 6.87G/9.45G [00:25<00:04, 521MB/s]
#
# model-00001-of-00002.safetensors:  73%|███▋ | 6.94G/9.45G [00:26<00:08, 312MB/s]
#
# model-00001-of-00002.safetensors:  74%|███▋ | 7.01G/9.45G [00:26<00:09, 251MB/s]
#
# model-00001-of-00002.safetensors:  75%|███▋ | 7.08G/9.45G [00:26<00:08, 276MB/s]
#
# model-00001-of-00002.safetensors:  76%|███▊ | 7.15G/9.45G [00:26<00:07, 326MB/s]
#
# model-00001-of-00002.safetensors:  77%|███▊ | 7.28G/9.45G [00:27<00:05, 399MB/s]
#
# model-00001-of-00002.safetensors:  78%|███▉ | 7.35G/9.45G [00:27<00:05, 417MB/s]
#
# model-00001-of-00002.safetensors:  79%|███▉ | 7.42G/9.45G [00:27<00:05, 390MB/s]
#
# model-00001-of-00002.safetensors:  79%|███▉ | 7.49G/9.45G [00:27<00:04, 410MB/s]
#
# model-00001-of-00002.safetensors:  80%|███▉ | 7.56G/9.45G [00:28<00:07, 270MB/s]
#
# model-00001-of-00002.safetensors:  81%|████ | 7.62G/9.45G [00:28<00:06, 285MB/s]
#
# model-00001-of-00002.safetensors:  81%|████ | 7.69G/9.45G [00:28<00:06, 293MB/s]
#
# model-00001-of-00002.safetensors:  82%|████ | 7.78G/9.45G [00:28<00:04, 373MB/s]
#
# model-00001-of-00002.safetensors:  84%|████▏| 7.92G/9.45G [00:28<00:03, 437MB/s]
#
# model-00001-of-00002.safetensors:  85%|████▎| 8.05G/9.45G [00:28<00:02, 550MB/s]
#
# model-00001-of-00002.safetensors:  87%|████▎| 8.18G/9.45G [00:29<00:02, 625MB/s]
#
# model-00001-of-00002.safetensors:  88%|████▍| 8.31G/9.45G [00:29<00:01, 734MB/s]
#
# model-00001-of-00002.safetensors:  89%|████▍| 8.44G/9.45G [00:29<00:01, 754MB/s]
#
# model-00001-of-00002.safetensors:  91%|████▌| 8.58G/9.45G [00:29<00:01, 691MB/s]
#
# model-00001-of-00002.safetensors:  92%|████▌| 8.71G/9.45G [00:29<00:01, 630MB/s]
#
# model-00001-of-00002.safetensors:  94%|████▋| 8.85G/9.45G [00:30<00:00, 678MB/s]
#
# model-00001-of-00002.safetensors:  95%|████▊| 8.98G/9.45G [00:30<00:00, 647MB/s]
#
# model-00001-of-00002.safetensors:  96%|████▊| 9.11G/9.45G [00:30<00:00, 740MB/s]
#
# model-00001-of-00002.safetensors:  98%|████▉| 9.25G/9.45G [00:30<00:00, 681MB/s]
#
# model-00001-of-00002.safetensors:  99%|████▉| 9.38G/9.45G [00:31<00:00, 486MB/s]
#
# model-00001-of-00002.safetensors: 100%|█████| 9.45G/9.45G [00:31<00:00, 299MB/s]
# Fetching 2 files: 100%|███████████████████████████| 2/2 [00:31<00:00, 15.94s/it]
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:04<00:00,  2.19s/it]
# generation_config.json: 100%|██████████████████| 147/147 [00:00<00:00, 1.32MB/s]
# /usr/local/lib/python3.12/dist-packages/accelerate/utils/modeling.py:1598: UserWarning: The following device_map keys do not match any submodules in the model: ['decoder.embed_tokens']
#   warnings.warn(
#  Loaded MONGO_URI from Kaggle Secrets
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://8e079640c9eaa0af4b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# /kaggle/working/yoga-rag-microapp/backend/rag/retriever.py:8: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py:2532: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(

# %%
# !cd /kaggle/working && zip -r yoga-rag-microapp.zip yoga-rag-microapp
# !ls -lh /kaggle/working/yoga-rag-microapp.zip
# Out:
#   adding: yoga-rag-microapp/ (stored 0%)
#   adding: yoga-rag-microapp/backend/ (stored 0%)
#   adding: yoga-rag-microapp/backend/llm/ (stored 0%)
#   adding: yoga-rag-microapp/backend/llm/__pycache__/ (stored 0%)
#   adding: yoga-rag-microapp/backend/llm/__pycache__/local_llm.cpython-312.pyc (deflated 31%)
#   adding: yoga-rag-microapp/backend/llm/local_llm.py (deflated 48%)
#   adding: yoga-rag-microapp/backend/rag/ (stored 0%)
#   adding: yoga-rag-microapp/backend/rag/retriever.py (deflated 48%)
#   adding: yoga-rag-microapp/backend/rag/ingest.py (deflated 52%)
#   adding: yoga-rag-microapp/backend/rag/__pycache__/ (stored 0%)
#   adding: yoga-rag-microapp/backend/rag/__pycache__/retriever.cpython-312.pyc (deflated 31%)
#   adding: yoga-rag-microapp/backend/rag/__pycache__/ingest.cpython-312.pyc (deflated 35%)
#   adding: yoga-rag-microapp/backend/safety.py (deflated 57%)
#   adding: yoga-rag-microapp/backend/__pycache__/ (stored 0%)
#   adding: yoga-rag-microapp/backend/__pycache__/config.cpython-312.pyc (deflated 33%)
#   adding: yoga-rag-microapp/backend/__pycache__/safety.cpython-312.pyc (deflated 28%)
#   adding: yoga-rag-microapp/backend/db.py (deflated 59%)
#   adding: yoga-rag-microapp/backend/config.py (deflated 55%)
#   adding: yoga-rag-microapp/faiss_index/ (stored 0%)
#   adding: yoga-rag-microapp/assets/ (stored 0%)
#   adding: yoga-rag-microapp/data/ (stored 0%)
#   adding: yoga-rag-microapp/data/yoga_docs/ (stored 0%)
#   adding: yoga-rag-microapp/data/yoga_docs/26_general_yoga_safety.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/05_trikonasana.txt (deflated 36%)
#   adding: yoga-rag-microapp/data/yoga_docs/07_virabhadrasana_2.txt (deflated 37%)
#   adding: yoga-rag-microapp/data/yoga_docs/04_bhujangasana.txt (deflated 36%)
#   adding: yoga-rag-microapp/data/yoga_docs/01_surya_namaskar.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/06_virabhadrasana_1.txt (deflated 38%)
#   adding: yoga-rag-microapp/data/yoga_docs/25_evening_yoga_routine.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/24_morning_yoga_routine.txt (deflated 42%)
#   adding: yoga-rag-microapp/data/yoga_docs/22_yoga_for_better_sleep.txt (deflated 44%)
#   adding: yoga-rag-microapp/data/yoga_docs/14_bhramari.txt (deflated 42%)
#   adding: yoga-rag-microapp/data/yoga_docs/23_yoga_and_mental_wellbeing.txt (deflated 46%)
#   adding: yoga-rag-microapp/data/yoga_docs/27_how_to_choose_yoga_practice.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/11_pranayama_basics.txt (deflated 47%)
#   adding: yoga-rag-microapp/data/yoga_docs/29_yoga_and_medical_conditions.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/17_contraindications_in_yoga.txt (deflated 46%)
#   adding: yoga-rag-microapp/data/yoga_docs/21_stress_management_with_yoga.txt (deflated 46%)
#   adding: yoga-rag-microapp/data/yoga_docs/20_yoga_after_injury.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/18_yoga_during_pregnancy.txt (deflated 46%)
#   adding: yoga-rag-microapp/data/yoga_docs/15_yoga_for_beginners.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/03_adho_mukha_svanasana.txt (deflated 39%)
#   adding: yoga-rag-microapp/data/yoga_docs/30_yoga_beginner_mistakes.txt (deflated 42%)
#   adding: yoga-rag-microapp/data/yoga_docs/09_setu_bandhasana.txt (deflated 36%)
#   adding: yoga-rag-microapp/data/yoga_docs/16_advanced_yoga.txt (deflated 45%)
#   adding: yoga-rag-microapp/data/yoga_docs/02_tadasana.txt (deflated 40%)
#   adding: yoga-rag-microapp/data/yoga_docs/19_yoga_for_high_bp.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/10_shavasana.txt (deflated 37%)
#   adding: yoga-rag-microapp/data/yoga_docs/12_anulom_vilom.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/28_when_to_stop_yoga.txt (deflated 43%)
#   adding: yoga-rag-microapp/data/yoga_docs/08_balasana.txt (deflated 35%)
#   adding: yoga-rag-microapp/data/yoga_docs/13_kapalbhati.txt (deflated 45%)
#   adding: yoga-rag-microapp/.gitignore (deflated 10%)
#   adding: yoga-rag-microapp/requirements.txt (deflated 32%)
#   adding: yoga-rag-microapp/frontend/ (stored 0%)
#   adding: yoga-rag-microapp/frontend/__pycache__/ (stored 0%)
#   adding: yoga-rag-microapp/frontend/__pycache__/app_gradio.cpython-312.pyc (deflated 36%)
#   adding: yoga-rag-microapp/frontend/app_gradio.py (deflated 55%)
#   adding: yoga-rag-microapp/.env.example (deflated 17%)
# -rw-r--r-- 1 root root 38K Jan 12 03:45 /kaggle/working/yoga-rag-microapp.zip
